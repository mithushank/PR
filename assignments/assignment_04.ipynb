# %%
import numpy as np
import matplotlib . pyplot as plt
from sklearn . datasets import make_circles
# Generate data with make_circles
np . random . seed (5)
X , y = make_circles ( n_samples =500 , factor =0.3 , noise =0.1)

# %%
plt.scatter (X [:, 0], X [:, 1], c=y, cmap=plt.cm.Paired)
plt.show()

# %%
X , y = make_circles ( n_samples =500 , factor =0.5 , noise =0.1)

# %%
def transformation_1 (x1,x2) :
    return x1,x2,x1**2 + x2**2


xt,yt,zt = transformation_1 (X [:, 0], X [:, 1])

# visualize in 3D

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure ()
ax = fig.add_subplot (111 , projection ='3d')
ax.scatter (xt,yt,zt , c=y, cmap=plt.cm.Paired)
plt.show()

# %%
def transformation_2 (x1,x2) :
    re0turn x1**2,x2**2,x1*x2


xt2, yt2, zt2 = transformation_2(X [:, 0], X [:, 1])

# visualize in 3D

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure ()
ax = fig.add_subplot (111 , projection ='3d')
ax.scatter (xt2, yt2, zt2  , c=y, cmap=plt.cm.Paired)
plt.show()

# %%
from sklearn.model_selection import train_test_split
import sklearn.svm as svm
from sklearn.metrics import accuracy_score, f1_score
import matplotlib.pyplot as plt

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Create an instance of the LinearSVC class and fit it to the training data
svm_classifier = svm.SVC(kernel='linear')
svm_classifier.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = svm_classifier.predict(X_test)

# Evaluate the performance of the model using metrics such as accuracy and F1 score
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("F1 score:", f1)

# Scatter plot of the data points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)

# Decision boundary
xx = np.linspace(X[:, 0].min(), X[:, 0].max(), 50)
yy = (svm_classifier.intercept_ - svm_classifier.coef_[0][0] * xx) / svm_classifier.coef_[0][1]
plt.plot(xx, yy, alpha=0.3, color='black')
plt.show()
# Out:
# Accuracy: 0.47
# F1 score: 0.5309734513274337

# %%
from sklearn.svm import SVC
from mpl_toolkits.mplot3d import Axes3D

# Create a linear SVM
svm_classifier = SVC(kernel='linear')

# Use the mapped 3-dimensional data
mapped_data = np.column_stack ((xt, yt, zt))

# Split the test and training data sets
X_train, X_test, y_train, y_test = train_test_split(mapped_data, y, test_size=0.2)

# Fit the SVM model
svm_classifier.fit(X_train, y_train)

# Make predictions using the model
y_pred = svm_classifier.predict(X_test)

# Visualize the decision boundary
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the points
ax.scatter(xt[y == 0], yt[y == 0], zt[y == 0], color='r', marker='o', label='Class 0')
ax.scatter(xt[y == 1],yt[y == 1], zt[y == 1], color='b', marker='^', label='Class 1')

# Plot the decision boundary
xx, yy = np.meshgrid(np.linspace(xt.min(), xt.max(), 50),
                     np.linspace(yt.min(), yt.max(), 50))
zz = (-svm_classifier.intercept_[0] - svm_classifier.coef_[0][0] * xx - svm_classifier.coef_[0][1] * yy) / svm_classifier.coef_[0][2]
ax.plot_surface(xx, yy, zz, alpha=0.3, color='gray')

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.legend()

# Show the plot
plt.show()

# Evaluate the performance of the model using metrics such as accuracy, precision, recall, and F1 score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 score:", f1_score(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 score: 1.0

# %%
from sklearn.svm import SVC
from mpl_toolkits.mplot3d import Axes3D

# Create a linear SVM
svm_classifier_2 = SVC(kernel='linear')

# Use the mapped 3-dimensional data
mapped_data_2 = np.column_stack((xt2, yt2, zt2))

X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(mapped_data_2, y, test_size=0.2)

# Fit the SVM model
svm_classifier_2.fit(X_train_2, y_train_2)

# Make predictions
y_pred_2 = svm_classifier_2.predict(X_test_2)

# Visualize the decision boundary
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the points
ax.scatter(xt2[y == 0], yt2[y == 0],zt2[y == 0], color='r', marker='o', label='Class 0')
ax.scatter(xt2[y == 1],yt2[y == 1], zt2[y == 1], color='b', marker='^', label='Class 1')

# Plot the decision boundary
xx, yy = np.meshgrid(np.linspace(xt2.min(), xt2.max(), 50),
                     np.linspace(yt2.min(), yt2.max(), 50))
zz = (-svm_classifier_2.intercept_[0] - svm_classifier_2.coef_[0][0] * xx - svm_classifier_2.coef_[0][1] * yy) / svm_classifier_2.coef_[0][2]
ax.plot_surface(xx, yy, zz, alpha=0.3, color='gray')

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.legend()

# Show the plot
plt.show()

# Evaluate the performance of the model using metrics such as accuracy, precision, recall, and F1 score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy:", accuracy_score(y_test_2, y_pred_2))
print("Precision:", precision_score(y_test_2, y_pred_2))
print("Recall:", recall_score(y_test_2, y_pred_2))
print("F1 score:", f1_score(y_test_2, y_pred_2))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 score: 1.0
